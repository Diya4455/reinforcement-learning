# %% [markdown]
# <a href="https://colab.research.google.com/github/Diya4455/reinforcement-learning/blob/main/RL_Exp_2_Part1_diya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
#np.random.seed(1)
x=np.random.randint(0, 50, 1000)
x
# Out:
# array([35,  5, 14, 40, 30, 41, 17, 10,  4, 47,  4, 15, 43,  7,  8, 10, 20,
#        46, 23, 12, 42, 34, 24, 49, 24, 13, 43, 28, 19,  5,  2, 21, 12, 15,
#         9, 40,  2,  3, 32, 19, 42, 49, 41, 21, 22, 32,  1, 14,  7, 16, 43,
#        38, 42, 42, 24, 13,  8, 47, 13, 29,  5,  2, 27, 45,  0, 16, 30, 19,
#         7, 45, 31, 49, 42, 28,  0,  6, 20, 31,  1,  2,  6, 13, 40, 42, 13,
#         9,  4,  6, 17, 41, 16, 14, 43, 23, 16, 15,  8,  9, 12,  2, 31, 13,
#        26,  3, 27, 28,  0, 35, 30, 11,  9, 15, 32, 32, 21, 16, 42,  9,  7,
#        37, 36, 15, 13, 34,  3, 11, 41, 47, 10, 12, 28, 23, 22, 10, 12, 30,
#        49, 39, 12,  0, 39, 45, 27,  3,  4, 24, 29, 30, 20, 27, 19, 47, 10,
#        12, 32, 15, 15, 12, 33, 46, 14, 42, 32, 29, 24, 36, 20, 14,  1, 43,
#        46, 37, 20,  0, 48, 36,  3, 17, 20, 40,  9,  5,  8, 24, 32, 10, 18,
#         5, 41,  7, 40, 33, 47, 31, 43,  0, 33, 19, 32, 30, 14, 10, 44,  0,
# ...

# %%
y=x=np.random.normal(0,1000,1000)
y
# Out:
# array([   85.64131947,   746.26844654,    87.30024071,  1364.15134087,
#          -28.40398254,   -54.55626777, -2467.5235069 ,   156.36512685,
#        -2117.19646765, -1414.4815058 , -1161.29111482,  -340.90248167,
#          542.72658985, -1612.8995676 ,  1533.98372693, -1113.65875969,
#         -229.51810127,     3.6190445 ,  1035.42627407,   237.59132545,
#        -1209.68566363,   907.69172812,  1617.65199948,  -393.33706775,
#        -1327.35861562, -1357.12448353,   -55.36936473,   256.5227755 ,
#         -115.28395487,   325.22450973,  -703.75967825,  -815.83697528,
#          828.65430321,  -400.95097877,   236.94539782,   253.22473987,
#         1317.22427036,  1072.83925341, -1465.72892782, -1098.62739988,
#         1947.99137632,  -659.15773674,   498.8551897 ,   166.95546388,
#        -1007.57711888,   717.039659  ,  -432.46755168,   641.41429187,
#        -1054.15803559,  -423.95754659,   210.9616174 ,  1019.72133482,
# ...

# %%
from ast import increment_lineno
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y=x+np.random.normal(0,10,1000)
y=x+np.random.normal(0,10,1000)

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.99995109],
#        [0.99995109, 1.        ]])

# %%
z=100-x

# %%
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter(x,z)
plt.show

np.corrcoef(x,z)
# Out:
# array([[ 1., -1.],
#        [-1.,  1.]])

# %%
import pandas as pd

df=pd.DataFrame({'a':np.random.randint(0,50,1000)})
df['b']=df['a']+np.random.normal(0,10,1000)
df['c']=100-df['a']+np.random.normal(0,5,1000)
df['d']=np.random.normal(0,10,1000)

df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.838143 -0.945303  0.026335
# b  0.838143  1.000000 -0.786268  0.035700
# c -0.945303 -0.786268  1.000000 -0.018768
# d  0.026335  0.035700 -0.018768  1.000000

# %%
pd.plotting.scatter_matrix(df, figsize = (6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)), df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar()
plt.show()
# Out:
# C:\Users\diyab\AppData\Local\Temp\ipykernel_7476\1944245446.py:4: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()
